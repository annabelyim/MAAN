# %%
import requests
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from stop_words import get_stop_words

# %%
def shmoop_themes(url, chara):
    html = urlopen(url)
    bs = BeautifulSoup(html.read(), 'html.parser')
    content = bs.find_all("div", {"data-element":"collapse_target"})
    for x in content:
        content = (x.find_all("p"))
    content = '\n'.join([c.text for c in content])
    
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    token = tokenizer.tokenize(content)
    stop_words = list(get_stop_words('en'))         
    nltk_words = list(stopwords.words('english')) 
    stop_words.extend(nltk_words)
    keywords = [word.lower() for word in token if not word.lower() in stop_words]
    keywords = [word.lower() for word in keywords if not word in chara]
    key_df = pd.DataFrame(keywords, columns = ['word'])
    key_df = key_df['word'].value_counts()
    key_df = key_df.to_frame()
    
    return key_df

# %%
much_ado_1 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/marriage",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_2 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/lies-and-deceit",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_3 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/language-and-communication",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_4 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/love",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_5 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/respect-and-reputation",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_6 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/transformation",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_7 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/gender",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_8 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/pride",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])
much_ado_9 = shmoop_themes("https://www.shmoop.com/study-guides/literature/much-ado-about-nothing/themes/maturity",
                     ['hero', 'claudio', 'beatrice', 'leonato', 'don', 'pedro', 'john','benedick', 'margaret', 
                      'borachio', 'conrad', 'dogberry', 'verges', 'antonio', 'balthasar', 'ursula', 'much', 'nothing',
                      'william', 'shakespeare'])

much_ado_1['title'] = 'Much Ado About Nothing'
much_ado_2['title'] = 'Much Ado About Nothing'
much_ado_3['title'] = 'Much Ado About Nothing'
much_ado_4['title'] = 'Much Ado About Nothing'
much_ado_5['title'] = 'Much Ado About Nothing'
much_ado_6['title'] = 'Much Ado About Nothing'
much_ado_7['title'] = 'Much Ado About Nothing'
much_ado_8['title'] = 'Much Ado About Nothing'
much_ado_9['title'] = 'Much Ado About Nothing'

# %%
pride_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/love',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/marriage',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/wealth',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/society-and-class',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/women-and-femininity',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/family',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/deceit',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/language-and-communication',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/principles',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/pride',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])
pride_11 = shmoop_themes('https://www.shmoop.com/study-guides/literature/pride-and-prejudice/themes/prejudice',
                     ['elizabeth', 'bennet', 'fitzwilliam', 'darcy', 'jane', 'mary', 'catherine', 'kitty',
                     'lydia', 'charles', 'caroline', 'bingley', 'hurst', 'wickham', 'mr', 'mrs', 'de', 'bourgh',
                     'pride', 'prejudice', 'jane', 'austen'])

pride_1['title'] = 'Pride and Prejudice'
pride_2['title'] = 'Pride and Prejudice'
pride_3['title'] = 'Pride and Prejudice'
pride_4['title'] = 'Pride and Prejudice'
pride_5['title'] = 'Pride and Prejudice'
pride_6['title'] = 'Pride and Prejudice'
pride_7['title'] = 'Pride and Prejudice'
pride_8['title'] = 'Pride and Prejudice'
pride_9['title'] = 'Pride and Prejudice'
pride_10['title'] = 'Pride and Prejudice'
pride_11['title'] = 'Pride and Prejudice'

# %%
gatsby_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/society-and-class',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/love',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/the-american-dream',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/wealth',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/memory-and-the-past',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/dissatisfaction',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/isolation',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/mortality',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/marriage',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/gender',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_11 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/lies-and-deceit',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_12 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/education',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_13 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/compassion-and-forgiveness',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])
gatsby_14 = shmoop_themes('https://www.shmoop.com/study-guides/literature/great-gatsby/themes/religion',
                     ['jay', 'gatsby', 'nick', 'tom', 'daisy', 'wilson', 'jordan', 'scott', 'fitzgerald',
                     'dan', 'cody', 'henry', 'gatz', 'ewing', 'klipspringer', 'michaelis', 'catherine',
                     'wilson', 'george', 'myrtle', 'baker', 'pammy', 'buchanan', 'carraway'])

gatsby_1['title'] = 'The Great Gatsby'
gatsby_2['title'] = 'The Great Gatsby'
gatsby_3['title'] = 'The Great Gatsby'
gatsby_4['title'] = 'The Great Gatsby'
gatsby_5['title'] = 'The Great Gatsby'
gatsby_6['title'] = 'The Great Gatsby'
gatsby_7['title'] = 'The Great Gatsby'
gatsby_8['title'] = 'The Great Gatsby'
gatsby_9['title'] = 'The Great Gatsby'
gatsby_10['title'] = 'The Great Gatsby'
gatsby_11['title'] = 'The Great Gatsby'
gatsby_12['title'] = 'The Great Gatsby'
gatsby_13['title'] = 'The Great Gatsby'
gatsby_14['title'] = 'The Great Gatsby'

# %%
scarlet_letter_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/revenge',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/women-and-femininity',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/compassion-and-forgiveness',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/sin',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/hypocrisy',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/guilt-and-blame',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/justice-and-judgment',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/isolation',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/the-supernatural',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/fate-and-free-will',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])
scarlet_letter_11 = shmoop_themes('https://www.shmoop.com/study-guides/literature/scarlet-letter/themes/man-and-the-natural-world',
                     ['hester', 'dimmesdale', 'pearl', 'chillingworth', 'letter', 'scarlet', 'nathaniel',
                     'hawthorne', 'chillingworth', 'roger', 'governor', 'bellingham', 'mistress', 'hibbins',
                     'john', 'wilson'])

scarlet_letter_1['title'] = 'The Scarlet Letter'
scarlet_letter_2['title'] = 'The Scarlet Letter'
scarlet_letter_3['title'] = 'The Scarlet Letter'
scarlet_letter_4['title'] = 'The Scarlet Letter'
scarlet_letter_5['title'] = 'The Scarlet Letter'
scarlet_letter_6['title'] = 'The Scarlet Letter'
scarlet_letter_7['title'] = 'The Scarlet Letter'
scarlet_letter_8['title'] = 'The Scarlet Letter'
scarlet_letter_9['title'] = 'The Scarlet Letter'
scarlet_letter_10['title'] = 'The Scarlet Letter'
scarlet_letter_11['title'] = 'The Scarlet Letter'

# %%
romeo_juliet_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/love',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/hate',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/sex',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/youth',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/art-and-culture',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/transience',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/mortality',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/gender',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/fate-and-free-will',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/marriage',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_11 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/family',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_12 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/foolishness-and-folly',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])
romeo_juliet_13 = shmoop_themes('https://www.shmoop.com/study-guides/literature/romeo-and-juliet/themes/exile',
                     ['romeo', 'juliet', 'william', 'shakespeare', 'capulet', 'montague', 'mercutio', 'tybalt',
                     'paris', 'friar', 'laurence', 'nurse', 'benvolio', 'lady', 'balthasar', 'apothecary',
                     'escalus', 'john', 'verona', 'prince', 'peter', 'abram', 'sampson', 'gregory'])

romeo_juliet_1['title'] = 'Romeo and Juliet'
romeo_juliet_2['title'] = 'Romeo and Juliet'
romeo_juliet_3['title'] = 'Romeo and Juliet'
romeo_juliet_4['title'] = 'Romeo and Juliet'
romeo_juliet_5['title'] = 'Romeo and Juliet'
romeo_juliet_6['title'] = 'Romeo and Juliet'
romeo_juliet_7['title'] = 'Romeo and Juliet'
romeo_juliet_8['title'] = 'Romeo and Juliet'
romeo_juliet_9['title'] = 'Romeo and Juliet'
romeo_juliet_10['title'] = 'Romeo and Juliet'
romeo_juliet_11['title'] = 'Romeo and Juliet'
romeo_juliet_12['title'] = 'Romeo and Juliet'
romeo_juliet_13['title'] = 'Romeo and Juliet'

# %%
macbeth_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/fate-and-free-will',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/ambition',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/power',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/versions-of-reality',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/gender',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/the-supernatural',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/violence',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])
macbeth_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/macbeth/themes/time',
                     ['macbeth', 'william', 'shakespeare', 'lady', 'banquo', 'duncan', 'fleance', 'donalbain',
                     'malcolm', 'macduff', 'lennox', 'ross', 'menteth', 'angus', 'caithness', 'witches'])

macbeth_1['title'] = 'Macbeth'
macbeth_2['title'] = 'Macbeth'
macbeth_3['title'] = 'Macbeth'
macbeth_4['title'] = 'Macbeth'
macbeth_5['title'] = 'Macbeth'
macbeth_6['title'] = 'Macbeth'
macbeth_7['title'] = 'Macbeth'
macbeth_8['title'] = 'Macbeth'

# %%
emma_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/foolishness-and-folly',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/marriage',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/home',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/society-and-class',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/transformation',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/respect-and-reputation',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/love',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/wealth',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/morality-and-ethics',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])
emma_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/emma/themes/gender',
                     ['emma', 'woodhouse', 'henry', 'george', 'knightley', 'frank', 'mr', 'jane', 'philip','elton',
                     'anne', 'taylor', 'miss', 'mrs', 'harriet', 'churchill', 'weston', 'austen'])

emma_1['title'] = 'Emma'
emma_2['title'] = 'Emma'
emma_3['title'] = 'Emma'
emma_4['title'] = 'Emma'
emma_5['title'] = 'Emma'
emma_6['title'] = 'Emma'
emma_7['title'] = 'Emma'
emma_8['title'] = 'Emma'
emma_9['title'] = 'Emma'
emma_10['title'] = 'Emma'

# %%
jane_eyre_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/marriage',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/education',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/appearances',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/society-and-class',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/the-supernatural',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/morality-and-ethics',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/foreignness-and-the-other',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])
jane_eyre_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/jane-eyre/themes/the-home',
                     ['jane', 'eyre','edward', 'fairfax','rochester','sarah', 'reed', 'john', 'eliza', 'thornfield',
                     'charlotte', 'Brontë'])

jane_eyre_1['title'] = 'Jane Eyre'
jane_eyre_2['title'] = 'Jane Eyre'
jane_eyre_3['title'] = 'Jane Eyre'
jane_eyre_4['title'] = 'Jane Eyre'
jane_eyre_5['title'] = 'Jane Eyre'
jane_eyre_6['title'] = 'Jane Eyre'
jane_eyre_7['title'] = 'Jane Eyre'
jane_eyre_8['title'] = 'Jane Eyre'

# %%
taming_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/transformation',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/art-and-culture',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/gender',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/marriage',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/education',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/society-and-class',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/family',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])
taming_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/taming-of-the-shrew/themes/language-and-communication',
                     ['christopher', 'sly', 'petruchio', 'katherine', 'kate', 'lucentio', 'bianca', 'taming', 'shrew',
                     'hortensio', 'baptista', 'lord', 'tranio', 'minola', 'william', 'shakespeare'])

taming_1['title'] = 'The Taming of the Shrew'
taming_2['title'] = 'The Taming of the Shrew'
taming_3['title'] = 'The Taming of the Shrew'
taming_4['title'] = 'The Taming of the Shrew'
taming_5['title'] = 'The Taming of the Shrew'
taming_6['title'] = 'The Taming of the Shrew'
taming_7['title'] = 'The Taming of the Shrew'
taming_8['title'] = 'The Taming of the Shrew'

# %%
like_it_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/love',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/foolishness-and-folly',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/contrasting-regions',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/gender',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/family',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/art-and-culture',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/transformation',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])
like_it_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/as-you-like-it/themes/philosophical-viewpoints',
                     ['orlando', 'rosalind', 'frederick', 'oliver', 'forest', 'arden', 'celia', 'william', 'shakespeare'])

like_it_1['title'] = 'As You Like It'
like_it_2['title'] = 'As You Like It'
like_it_3['title'] = 'As You Like It'
like_it_4['title'] = 'As You Like It'
like_it_5['title'] = 'As You Like It'
like_it_6['title'] = 'As You Like It'
like_it_7['title'] = 'As You Like It'
like_it_8['title'] = 'As You Like It'

# %%
earnest_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/lies-and-deceit',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/marriage',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/respect-and-reputation',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/society-and-class',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/gender',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/versions-of-reality-romance',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/love',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])
earnest_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/importance-of-being-earnest/themes/foolishness-and-folly',
                     ['john', 'worthing', 'jack', 'algernon', 'moncrieff', 'cecily', 'ernest', 'bracknell', 'earnest',
                     'lady', 'miss', 'algy', 'gwendolen', 'oscar', 'wilde'])

earnest_1['title'] = 'The Importance of Being Earnest' 
earnest_2['title'] = 'The Importance of Being Earnest' 
earnest_3['title'] = 'The Importance of Being Earnest' 
earnest_4['title'] = 'The Importance of Being Earnest' 
earnest_5['title'] = 'The Importance of Being Earnest' 
earnest_6['title'] = 'The Importance of Being Earnest' 
earnest_7['title'] = 'The Importance of Being Earnest' 
earnest_8['title'] = 'The Importance of Being Earnest'

# %%
awakening_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/identity',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/women-and-femininity',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/marriage',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/love',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/society-and-class',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/repression',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/art-and-culture',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/family',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/respect-and-reputation',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])
awakening_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/the-awakening/themes/life-consciousness-and-existence',
                     ['edna', 'robert', 'léonce', 'ratignolle', 'mademoiselle', 'awakening', 'kate', 'chopin'])

awakening_1['title'] = 'The Awakening'
awakening_2['title'] = 'The Awakening'
awakening_3['title'] = 'The Awakening'
awakening_4['title'] = 'The Awakening'
awakening_5['title'] = 'The Awakening'
awakening_6['title'] = 'The Awakening'
awakening_7['title'] = 'The Awakening'
awakening_8['title'] = 'The Awakening'
awakening_9['title'] = 'The Awakening'
awakening_10['title'] = 'The Awakening'

# %%
othello_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/jealousy',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/race',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/gender',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/sex',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/marriage',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/manipulation',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/warfare',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/hate',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])
othello_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/othello/themes/identity',
                     ['othello', 'iago', 'desdemona', 'cassio', 'roderigo', 'brabantio', 'emilia', 'duke', 'venice',
                     'cyprus', 'william', 'shakespeare'])

othello_1['title'] = 'Othello'
othello_2['title'] = 'Othello'
othello_3['title'] = 'Othello'
othello_4['title'] = 'Othello'
othello_5['title'] = 'Othello'
othello_6['title'] = 'Othello'
othello_7['title'] = 'Othello'
othello_8['title'] = 'Othello'
othello_9['title'] = 'Othello'

# %%
twelfth_night_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/art-and-culture',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/love',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/gender',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/language-and-communication',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/society-and-class',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/rules-and-order',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/lies-and-deceit',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])
twelfth_night_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/twelfth-night/themes/foolishness-and-folly',
                     ['orsino', 'viola', 'olivia', 'sir', 'toby', 'maria', 'sebastian', 'malvolio', 'duke', 
                      'countess', 'william', 'shakespeare'])

twelfth_night_1['title'] = 'Twelfth Night'
twelfth_night_2['title'] = 'Twelfth Night'
twelfth_night_3['title'] = 'Twelfth Night'
twelfth_night_4['title'] = 'Twelfth Night'
twelfth_night_5['title'] = 'Twelfth Night'
twelfth_night_6['title'] = 'Twelfth Night'
twelfth_night_7['title'] = 'Twelfth Night'
twelfth_night_8['title'] = 'Twelfth Night'

# %%
life_pi_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/religion',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/literature-and-writing',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/man-and-the-natural-world',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/spirituality',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/suffering',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/science',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/fear',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/mortality',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])
life_pi_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/life-of-pi/themes/madness',
                     ['mr.', 'adirubasamy', 'pi', 'yann', 'martel', 'piscine', 'molitor', 'patel', 'thirsty',
                      'richard', 'parker'])

life_pi_1['title'] = 'Life of Pi'
life_pi_2['title'] = 'Life of Pi'
life_pi_3['title'] = 'Life of Pi'
life_pi_4['title'] = 'Life of Pi'
life_pi_5['title'] = 'Life of Pi'
life_pi_6['title'] = 'Life of Pi'
life_pi_7['title'] = 'Life of Pi'
life_pi_8['title'] = 'Life of Pi'
life_pi_9['title'] = 'Life of Pi'

# %%
kite_runner_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/friendship',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/betrayal',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/warfare',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/principles',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/innocence',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/race',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/men-and-masculinity',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/religion',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/admiration',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])
kite_runner_10 = shmoop_themes('https://www.shmoop.com/study-guides/literature/kite-runner/themes/literature-and-writing',
                     ['amir', 'baba', 'hassan', 'sohrab', 'rahim', 'assef', 'soraya', 'ali', 'general', 
                     'sahib', 'farid', 'khala', 'taheri', 'afghanistan', 'kite', 'runner', 'kabul'])


kite_runner_1['title'] = 'The Kite Runner'
kite_runner_2['title'] = 'The Kite Runner'
kite_runner_3['title'] = 'The Kite Runner'
kite_runner_4['title'] = 'The Kite Runner'
kite_runner_5['title'] = 'The Kite Runner'
kite_runner_6['title'] = 'The Kite Runner'
kite_runner_7['title'] = 'The Kite Runner'
kite_runner_8['title'] = 'The Kite Runner'
kite_runner_9['title'] = 'The Kite Runner'
kite_runner_10['title'] = 'The Kite Runner'

# %%
handmaid_tale_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/identity',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/children',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/marriage',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/passivity',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/love',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/women-and-femininity',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/the-home',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/freedom-and-confinement',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])
handmaid_tale_9 = shmoop_themes('https://www.shmoop.com/study-guides/literature/handmaids-tale/themes/reading-writing-and-storytelling',
                     ['offred', 'moira', 'serena', 'joy', 'commander', 'nick', 'aunt', 'lydia', 'luke',
                     'ofglen', 'rita', 'cora', 'gilead', 'tale', 'handmaids', 'margaret', 'atwood', 'pieixoto', 
                      'narrator'])

handmaid_tale_1['title'] = "The Handmaid's Tale"
handmaid_tale_2['title'] = "The Handmaid's Tale"
handmaid_tale_3['title'] = "The Handmaid's Tale"
handmaid_tale_4['title'] = "The Handmaid's Tale"
handmaid_tale_5['title'] = "The Handmaid's Tale"
handmaid_tale_6['title'] = "The Handmaid's Tale"
handmaid_tale_7['title'] = "The Handmaid's Tale"
handmaid_tale_8['title'] = "The Handmaid's Tale"
handmaid_tale_9['title'] = "The Handmaid's Tale"

# %%
beloved_1 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/the-home',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_2 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/men-and-masculinity',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_3 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/love',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_4 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/slavery',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_5 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/family',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_6 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/memory-and-the-past',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_7 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/the-supernatural',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])
beloved_8 = shmoop_themes('https://www.shmoop.com/study-guides/literature/beloved/themes/community',
                     ['sethe', 'beloved', 'paul', 'toni', 'morrison', 'denver', 'halle', 'suggs', 'amy', 'vashti'])

beloved_1['title'] = "Beloved"
beloved_2['title'] = "Beloved"
beloved_3['title'] = "Beloved"
beloved_4['title'] = "Beloved"
beloved_5['title'] = "Beloved"
beloved_6['title'] = "Beloved"
beloved_7['title'] = "Beloved"
beloved_8['title'] = "Beloved"

# %%
shmoop_themes_df = [much_ado_1, much_ado_2, much_ado_3, much_ado_4, much_ado_5, much_ado_6, much_ado_7, much_ado_8, 
                    much_ado_9, pride_1, pride_2, pride_3, pride_4, pride_5, pride_6, pride_7, pride_8, pride_9,
                    pride_10, pride_11, 
                    gatsby_1, gatsby_2, gatsby_3, gatsby_4, gatsby_5, gatsby_6, gatsby_7, gatsby_8,
                    gatsby_9, gatsby_10, gatsby_11, gatsby_12, gatsby_13, gatsby_14, 
                    scarlet_letter_1, scarlet_letter_2, scarlet_letter_3, scarlet_letter_4, scarlet_letter_5, 
                    scarlet_letter_6, scarlet_letter_7, scarlet_letter_8, scarlet_letter_9, scarlet_letter_10, scarlet_letter_11, 
                    romeo_juliet_1, romeo_juliet_2, romeo_juliet_3, romeo_juliet_4, romeo_juliet_5, romeo_juliet_6, 
                    romeo_juliet_7, romeo_juliet_8, romeo_juliet_9, romeo_juliet_10, romeo_juliet_11, romeo_juliet_12, romeo_juliet_13,
                    macbeth_1, macbeth_2, macbeth_3, macbeth_4, macbeth_5, macbeth_6, macbeth_7, macbeth_8, 
                    emma_1, emma_2, emma_3, emma_4, emma_5, emma_6, emma_7, emma_8, emma_9, emma_10, 
                    jane_eyre_1, jane_eyre_2, jane_eyre_3, jane_eyre_4, jane_eyre_5, jane_eyre_6, jane_eyre_7, jane_eyre_8,
                    taming_1, taming_2, taming_3, taming_4, taming_5, taming_6, taming_7, taming_8,
                    like_it_1, like_it_2, like_it_3, like_it_4, like_it_5, like_it_6, like_it_7, like_it_8,
                    earnest_1, earnest_2, earnest_3, earnest_4, earnest_5, earnest_6, earnest_7, earnest_8,
                    awakening_1, awakening_2, awakening_3, awakening_4, awakening_5, awakening_6, awakening_7,
                    awakening_8, awakening_9, awakening_10, 
                    othello_1, othello_2, othello_3, othello_4, othello_5, othello_6, othello_7, othello_8, othello_9,
                    twelfth_night_1, twelfth_night_2, twelfth_night_3, twelfth_night_4, twelfth_night_5, twelfth_night_6,
                    twelfth_night_7, twelfth_night_8,
                    life_pi_1, life_pi_2, life_pi_3, life_pi_4, life_pi_5, life_pi_6, life_pi_7, life_pi_8, life_pi_9,
                    kite_runner_1, kite_runner_2, kite_runner_3, kite_runner_4, kite_runner_5, kite_runner_6, kite_runner_7,
                    kite_runner_8, kite_runner_9, kite_runner_10,
                    handmaid_tale_1, handmaid_tale_2, handmaid_tale_3, handmaid_tale_4, handmaid_tale_5, handmaid_tale_6,
                    handmaid_tale_7, handmaid_tale_8, handmaid_tale_9,
                    beloved_1, beloved_2, beloved_3, beloved_4, beloved_5, beloved_6, beloved_7, beloved_8]

keys_df = pd.DataFrame()
for df in shmoop_themes_df:
    keys_df = keys_df.append(df)

# %%
keys_df.to_csv("shmoop_themes.csv")

# %%
print(keys_df.title.unique())
# Out:
# ['Much Ado About Nothing' 'Pride and Prejudice' 'The Great Gatsby'
#  'The Scarlet Letter' 'Romeo and Juliet' 'Macbeth' 'Emma' 'Jane Eyre'
#  'The Taming of the Shrew' 'As You Like It'
#  'The Importance of Being Earnest' 'The Awakening' 'Othello'
#  'Twelfth Night' 'Life of Pi' 'The Kite Runner' "The Handmaid's Tale"
#  'Beloved']
